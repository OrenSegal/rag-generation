# %%
import pandas as pd
df = pd.read_csv('../../top_rated_wines.csv')
df = df[df['variety'].notna()] # remove any NaN values as it blows up serialization
data = df.sample(700).to_dict('records') # Get only 700 records. More records will make it slower to index
len(data)
# Out:
# 700

# %%
from qdrant_client import models, QdrantClient
from sentence_transformers import SentenceTransformer

# %%
encoder = SentenceTransformer('all-MiniLM-L6-v2') # Model to create embeddings
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]

# %%
# create the vector database client
qdrant = QdrantClient(":memory:") # Create in-memory Qdrant instance

# %%
# Create collection to store wines
qdrant.recreate_collection(
    collection_name="top_wines",
    vectors_config=models.VectorParams(
        size=encoder.get_sentence_embedding_dimension(), # Vector size is defined by used model
        distance=models.Distance.COSINE
    )
)
# Out:
# /var/folders/dg/1nl94b9j41j072s2yp20q5n80000gn/T/ipykernel_34446/3075695827.py:5: FutureWarning: The `get_sentence_embedding_dimension` method has been renamed to `get_embedding_dimension`.
#   size=encoder.get_sentence_embedding_dimension(), # Vector size is defined by used model
# /var/folders/dg/1nl94b9j41j072s2yp20q5n80000gn/T/ipykernel_34446/3075695827.py:2: DeprecationWarning: `recreate_collection` method is deprecated and will be removed in the future. Use `collection_exists` to check collection existence and `create_collection` instead.
#   qdrant.recreate_collection(
# True

# %%
# vectorize!
qdrant.upload_points(
    collection_name="top_wines",
    points=[
        models.PointStruct(
            id=idx,
            vector=encoder.encode(doc["notes"]).tolist(),
            payload=doc,
        ) for idx, doc in enumerate(data) # data is the variable holding all the wines
    ]
)

# %%
user_prompt = "Suggest me an amazing Malbec wine from Argentina"

# %%
# Search time for awesome wines!

hits = qdrant.query_points(
    collection_name="top_wines",
    query=encoder.encode(user_prompt).tolist(),
    limit=3
).points
for hit in hits:
  print(hit.payload, "score:", hit.score)
# Out:
# {'name': 'Catena Zapata Argentino Vineyard Malbec 2004', 'region': 'Argentina', 'variety': 'Red Wine', 'rating': 98.0, 'notes': '"The single-vineyard 2004 Malbec Argentino Vineyard spent 17 months in new French oak. Remarkably fragrant and complex aromatically, it offers up aromas of wood smoke, creosote, pepper, clove, black cherry, and blackberry. Made in a similar, elegant style, it is the most structured of the three single vineyard wines, needing a minimum of a decade of additional cellaring. It should easily prove to be a 25-40 year wine. It is an exceptional achievement in Malbec. When all is said and done, Catena Zapata is the Argentina winery of reference – the standard of excellence for comparing all others. The brilliant, forward-thinking Nicolas Catena remains in charge, with his daughter, Laura, playing an increasingly large role. The Catena Zapata winery is an essential destination for fans of both architecture and wine in Mendoza. It is hard to believe, given the surge in popularity of Malbec in recent years, that Catena Zapata only began exporting Malbec to the United States in 1994."'} score: 0.6377782895442721
# {'name': 'Catena Zapata Adrianna Vineyard Malbec 2004', 'region': 'Argentina', 'variety': 'Red Wine', 'rating': 97.0, 'notes': '"The single-vineyard 2004 Malbec Adrianna Vineyard from the Gualtallary district is inky purple with aromas of wood smoke, pencil lead, game, black cherry, and blackberry liqueur. Opulent, full-flavored, yet remarkably light on its feet, this medium to full-bodied Malbec is all about pleasure. It will certainly evolve for a decade but is hard to resist now. It is a fine test of one\'s ability to defer immediate gratification. When all is said and done, Catena Zapata is the Argentina winery of reference – the standard of excellence for comparing all others. The brilliant, forward-thinking Nicolas Catena remains in charge, with his daughter, Laura, playing an increasingly large role. The Catena Zapata winery is an essential destination for fans of both architecture and wine in Mendoza. It is hard to believe, given the surge in popularity of Malbec in recent years, that Catena Zapata only began exporting Malbec to the United States in 1994."'} score: 0.6117574888215465
# {'name': 'Altos las Hormigas Gualtallary Malbec 2016', 'region': 'Uco Valley, Mendoza, Argentina', 'variety': 'Red Wine', 'rating': 96.0, 'notes': 'A solid violet red color reveals a dense, concentrated, compact wine. Notes of spices and minerality make a complex nose. On the palate, a supple entry, dark berries and spices. A very structured and quite wild Malbec, with firm fine-grain tannins, showing its calcareous foundations and columns. The mouth feel is full of thrilling freshness and balance, with a long and persistent finish.'} score: 0.605613338180699

# %%
# define a variable to hold the search results
search_results = [hit.payload for hit in hits]

# %%
# Now time to connect to the local large language model
from openai import OpenAI
client = OpenAI(
    base_url="http://127.0.0.1:8080/v1", # "http://<Your api-server IP>:port"
    api_key = "sk-no-key-required"
)
completion = client.chat.completions.create(
    model="LLaMA_CPP",
    messages=[
        {"role": "system", "content": "You are chatbot, a wine specialist. Your top priority is to help guide users into selecting amazing wine and guide them with their requests."},
        {"role": "user", "content": "Suggest me an amazing Malbec wine from Argentina"},
        {"role": "assistant", "content": str(search_results)}
    ]
)
print(completion.choices[0].message)
# Out:
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File ~/Documents/GitHub/rag-generation/.venv/lib/python3.12/site-packages/httpx2/_transports/default.py:98, in map_httpcore_exceptions()
#      97 try:
# ---> 98     yield
#      99 except Exception as exc:
#
# File ~/Documents/GitHub/rag-generation/.venv/lib/python3.12/site-packages/httpx2/_transports/default.py:245, in HTTPTransport.handle_request(self, request)
#     244 with map_httpcore_exceptions():
# --> 245     resp = self._pool.handle_request(req)
#     247 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/Documents/GitHub/rag-generation/.venv/lib/python3.12/site-packages/httpcore2/_sync/connection_pool.py:242, in ConnectionPool.handle_request(self, request)
#     241     self._close_connections(closing)
# --> 242     raise exc from None
#     244 # Return the response. Note that in this case we still have to manage
#     245 # the point at which the response is closed.
#
# File ~/Documents/GitHub/rag-generation/.venv/lib/python3.12/site-packages/httpcore2/_sync/connection_pool.py:224, in ConnectionPool.handle_request(self, request)
#     222 try:
#     223     # Send the request on the assigned connection.
# --> 224     response = connection.handle_request(pool_request.request)
#     225 except ConnectionNotAvailable:
#     226     # In some cases a connection may initially be available to
#     227     # handle a request, but then become unavailable.
#     228     #
#     229     # In this case we clear the connection and try again.
#
# File ~/Documents/GitHub/rag-generation/.venv/lib/python3.12/site-packages/httpcore2/_sync/connection.py:94, in HTTPConnection.handle_request(self, request)
#      93     self._connect_failed = True
# ---> 94     raise exc
#      96 return self._connection.handle_request(request)
#
# File ~/Documents/GitHub/rag-generation/.venv/lib/python3.12/site-packages/httpcore2/_sync/connection.py:74, in HTTPConnection.handle_request(self, request)
#      73 if self._connection is None:
# ---> 74     stream = self._connect(request)
#      76     ssl_object = stream.get_extra_info("ssl_object")
#
# File ~/Documents/GitHub/rag-generation/.venv/lib/python3.12/site-packages/httpcore2/_sync/connection.py:117, in HTTPConnection._connect(self, request)
#     116 with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 117     stream = self._network_backend.connect_tcp(**kwargs)
#     118     trace.return_value = stream
#
# File ~/Documents/GitHub/rag-generation/.venv/lib/python3.12/site-packages/httpcore2/_backends/sync.py:203, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     198 exc_map: ExceptionMapping = {
#     199     socket.timeout: ConnectTimeout,
#     200     OSError: ConnectError,
#     201 }
# --> 203 with map_exceptions(exc_map):
#     204     sock = socket.create_connection(
#     205         address,
#     206         timeout,
#     207         source_address=source_address,
#     208     )
#
# File /opt/anaconda3/lib/python3.12/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(value)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File ~/Documents/GitHub/rag-generation/.venv/lib/python3.12/site-packages/httpcore2/_exceptions.py:17, in map_exceptions(map)
#      16     if isinstance(exc, from_exc):
# ---> 17         raise to_exc(exc) from exc
#      18 raise
#
# ConnectError: [Errno 61] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# File ~/Documents/GitHub/rag-generation/.venv/lib/python3.12/site-packages/openai/_base_client.py:1076, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1075 try:
# -> 1076     response = self._send_request(
#    1077         request,
#    1078         stream=stream or self._should_stream_response_body(request=request),
#    1079         **kwargs,
#    1080     )
#    1081 except timeout_exceptions() as err:
#
# File ~/Documents/GitHub/rag-generation/.venv/lib/python3.12/site-packages/openai/_client.py:591, in OpenAI._send_request(self, request, stream, **kwargs)
#     583 @override
#     584 def _send_request(
#     585     self,
#    (...)    589     **kwargs: Unpack[HttpxSendArgs],
#     590 ) -> httpx2.Response:
# --> 591     response = self._send_with_auth_retry(request, stream=stream, **kwargs)
#     592     if self._provider_runtime is not None and self._provider_runtime.normalize_response is not None:
#
# File ~/Documents/GitHub/rag-generation/.venv/lib/python3.12/site-packages/openai/_client.py:570, in OpenAI._send_with_auth_retry(self, request, stream, retried, **kwargs)
#     569 else:
# --> 570     response = super()._send_request(request, stream=stream, **kwargs)
#     571 if response.status_code != 401 or self._workload_identity_auth is None or used_access_token is None:
#
# File ~/Documents/GitHub/rag-generation/.venv/lib/python3.12/site-packages/openai/_base_client.py:999, in SyncAPIClient._send_request(self, request, stream, **kwargs)
#     992 def _send_request(
#     993     self,
#     994     request: httpx2.Request,
#    (...)    997     **kwargs: Unpack[HttpxSendArgs],
#     998 ) -> httpx2.Response:
# --> 999     return self._client.send(request, stream=stream, **kwargs)
#
# File ~/Documents/GitHub/rag-generation/.venv/lib/python3.12/site-packages/httpx2/_client.py:980, in Client.send(self, request, stream, auth, follow_redirects)
#     978 auth = self._build_request_auth(request, auth)
# --> 980 response = self._send_handling_auth(
#     981     request,
#     982     auth=auth,
#     983     follow_redirects=follow_redirects,
#     984     history=[],
#     985 )
#     986 try:
#
# File ~/Documents/GitHub/rag-generation/.venv/lib/python3.12/site-packages/httpx2/_client.py:1008, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#    1007 while True:
# -> 1008     response = self._send_handling_redirects(
#    1009         request,
#    1010         follow_redirects=follow_redirects,
#    1011         history=history,
#    1012     )
#    1013     try:
#
# File ~/Documents/GitHub/rag-generation/.venv/lib/python3.12/site-packages/httpx2/_client.py:1043, in Client._send_handling_redirects(self, request, follow_redirects, history)
#    1041     hook(request)
# -> 1043 response = self._send_single_request(request)
#    1044 try:
#
# File ~/Documents/GitHub/rag-generation/.venv/lib/python3.12/site-packages/httpx2/_client.py:1076, in Client._send_single_request(self, request)
#    1075 with request_context(request=request):
# -> 1076     response = transport.handle_request(request)
#    1078 assert isinstance(response.stream, SyncByteStream)
#
# File ~/Documents/GitHub/rag-generation/.venv/lib/python3.12/site-packages/httpx2/_transports/default.py:244, in HTTPTransport.handle_request(self, request)
#     232 req = httpcore2.Request(
#     233     method=request.method,
#     234     url=httpcore2.URL(
#    (...)    242     extensions=request.extensions,
#     243 )
# --> 244 with map_httpcore_exceptions():
#     245     resp = self._pool.handle_request(req)
#
# File /opt/anaconda3/lib/python3.12/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(value)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File ~/Documents/GitHub/rag-generation/.venv/lib/python3.12/site-packages/httpx2/_transports/default.py:115, in map_httpcore_exceptions()
#     114 message = str(exc)
# --> 115 raise mapped_exc(message) from exc
#
# ConnectError: [Errno 61] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# APIConnectionError                        Traceback (most recent call last)
# Cell In[10], line 7
#       3 client = OpenAI(
#       4     base_url="http://127.0.0.1:8080/v1", # "http://<Your api-server IP>:port"
#       5     api_key = "sk-no-key-required"
#       6 )
# ----> 7 completion = client.chat.completions.create(
#       8     model="LLaMA_CPP",
#       9     messages=[
#      10         {"role": "system", "content": "You are chatbot, a wine specialist. Your top priority is to help guide users into selecting amazing wine and guide them with their requests."},
#
# File ~/Documents/GitHub/rag-generation/.venv/lib/python3.12/site-packages/openai/_utils/_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File ~/Documents/GitHub/rag-generation/.venv/lib/python3.12/site-packages/openai/resources/chat/completions/completions.py:1308, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, moderation, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_options, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1259 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1260 def create(
#    1261     self,
#    (...)   1305     timeout: float | httpx2.Timeout | None | NotGiven = not_given,
#    1306 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1307     validate_response_format(response_format)
# -> 1308     return self._post(
#    1309         "/chat/completions",
#    1310         body=maybe_transform(
#    1311             {
#    1312                 "messages": messages,
#    1313                 "model": model,
#    1314                 "audio": audio,
#    1315                 "frequency_penalty": frequency_penalty,
#    1316                 "function_call": function_call,
#    1317                 "functions": functions,
#    1318                 "logit_bias": logit_bias,
#    1319                 "logprobs": logprobs,
#    1320                 "max_completion_tokens": max_completion_tokens,
#    1321                 "max_tokens": max_tokens,
#    1322                 "metadata": metadata,
#    1323                 "modalities": modalities,
#    1324                 "moderation": moderation,
#    1325                 "n": n,
#    1326                 "parallel_tool_calls": parallel_tool_calls,
#    1327                 "prediction": prediction,
#    1328                 "presence_penalty": presence_penalty,
#    1329                 "prompt_cache_key": prompt_cache_key,
#    1330                 "prompt_cache_options": prompt_cache_options,
#    1331                 "prompt_cache_retention": prompt_cache_retention,
#    1332                 "reasoning_effort": reasoning_effort,
#    1333                 "response_format": response_format,
#    1334                 "safety_identifier": safety_identifier,
#    1335                 "seed": seed,
#    1336                 "service_tier": service_tier,
#    1337                 "stop": stop,
#    1338                 "store": store,
#    1339                 "stream": stream,
#    1340                 "stream_options": stream_options,
#    1341                 "temperature": temperature,
#    1342                 "tool_choice": tool_choice,
#    1343                 "tools": tools,
#    1344                 "top_logprobs": top_logprobs,
#    1345                 "top_p": top_p,
#    1346                 "user": user,
#    1347                 "verbosity": verbosity,
#    1348                 "web_search_options": web_search_options,
#    1349             },
#    1350             completion_create_params.CompletionCreateParamsStreaming
#    1351             if stream
#    1352             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1353         ),
#    1354         options=make_request_options(
#    1355             extra_headers=extra_headers,
#    1356             extra_query=extra_query,
#    1357             extra_body=extra_body,
#    1358             timeout=timeout,
#    1359             security={"bearer_auth": True},
#    1360         ),
#    1361         cast_to=ChatCompletion,
#    1362         stream=stream or False,
#    1363         stream_cls=Stream[ChatCompletionChunk],
#    1364     )
#
# File ~/Documents/GitHub/rag-generation/.venv/lib/python3.12/site-packages/openai/_base_client.py:1368, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1359     warnings.warn(
#    1360         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1361         "Please pass raw bytes via the `content` parameter instead.",
#    1362         DeprecationWarning,
#    1363         stacklevel=2,
#    1364     )
#    1365 opts = FinalRequestOptions.construct(
#    1366     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1367 )
# -> 1368 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Documents/GitHub/rag-generation/.venv/lib/python3.12/site-packages/openai/_base_client.py:1111, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1108         continue
#    1110     log.debug("Raising connection error")
# -> 1111     raise APIConnectionError(request=request) from err
#    1113 log.debug(
#    1114     "HTTP Response: %s %i",
#    1115     get_http_method_for_logging(request.method),
#    1116     response.status_code,
#    1117 )
#    1118 log.debug("request_id: %s", response.headers.get("x-request-id"))
#
# APIConnectionError: Connection error.
